# %%
    page = requests.get(link)
    soup = BS(page.content, 'html.parser')
    idk=soup.select('div[class="round"]')
    i=1
    maybe = []
    for thing in list(range(1,100)):
        if i%3 !=0:
            try:
                maybe.append(idk[k].select('div')[i].select('span')[0].string)
                i+=1
            except:
                i+=1
                continue
        else:
            i+=1
            continue
    return maybe

# %%
https://www.sports-reference.com/cbb/postseason/2002-ncaa.html

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
page = requests.get('https://www.sports-reference.com/cbb/postseason/2002-ncaa.html')
soup = BS(page.content, 'html.parser')
idk=soup.select('div[class="round"]')
idk[0].select('a[href^=/cbb/schools]')[1].string
# Out:
# 'Siena'

# %%
names_ = []
for thing in range(0,1000):
    try:
        names_.append(idk[0].select('a[href^=/cbb/schools]')[thing].string)
    except:
        break

# %%
names_
# Out:
# ['Maryland',
#  'Siena',
#  'Wisconsin',
#  "St. John's (NY)",
#  'Marquette',
#  'Tulsa',
#  'Kentucky',
#  'Valparaiso',
#  'Texas Tech',
#  'Southern Illinois',
#  'Georgia',
#  'Murray State',
#  'NC State',
#  'Michigan State',
#  'UConn',
#  'Hampton']

# %%
i=1
maybe = []
for thing in list(range(1,100)):
    if i%3 !=0:
        try:
            maybe.append(idk[k].select('div')[i].select('span')[0].string)
            i+=1
        except:
            i+=1
            continue
    else:
        i+=1
        continue

# %%
def get_team_names (link,k):
    page = requests.get(link)
    soup = BS(page.content, 'html.parser')
    idk=soup.select('div[class="round"]')
    maybe = []
    for thing in list(range(0,100)):
        try:
            maybe.append(idk[k].select('a[href^=/cbb/schools]')[thing].string)
        except:
            continue
    return maybe

# %%
def get_teams_get (link):
    team_names = []
    for thing in list(range(0,23)):
        new=get_team_names (link,thing)
        team_names.extend(new)
    team_names.pop(-1)
    team_names.pop(30)
    team_names.pop(60)
    team_names.pop(90)
    team_names.pop(120)
    return team_names

# %%
def get_teams (link,k):
    page = requests.get(link)
    soup = BS(page.content, 'html.parser')
    idk=soup.select('div[class="round"]')
    i=1
    maybe = []
    for thing in list(range(1,100)):
        if i%3 !=0:
            try:
                maybe.append(idk[k].select('div')[i].select('span')[0].string)
                i+=1
            except:
                i+=1
                continue
        else:
            i+=1
            continue
    return maybe

# %%
def split_up_teams (link):
    All_teams = []
    for thing in list(range(0,23)):
        new=get_teams (link,thing)
        All_teams.extend(new)
    All_teams.pop(-1)
    All_teams.pop(30)
    All_teams.pop(60)
    All_teams.pop(90)
    All_teams.pop(120)
    return All_teams

# %%
All_teams=split_up_teams('https://www.sports-reference.com/cbb/postseason/2002-ncaa.html')

# %%
#all_the teams - rankings in order for a year
len(All_teams)
# Out:
# 126

# %%
rankings= []
for thing in All_teams:
    rankings.append(int(thing))

# %%
team_names=get_teams_get ('https://www.sports-reference.com/cbb/postseason/2002-ncaa.html')

# %%
#all the team names in order
team_names[0]
# Out:
# 'Maryland'

# %%
def get_winners (link):
    page = requests.get(link)
    soup = BS(page.content, 'html.parser')
    idk=soup.select('div[class="round"]')
    i=0
    k=0
    winners=[]
    for thing in list(range(1,100)):
        if k == 22:
            break
        elif k == 0 or k== 1 or k==2 or k==3 or k==5 or k==6 or k==7 or k==8 or k==10 or k==11 or k==12 or k==13 or k==15 or k==16 or k==17 or k==18 or k==20 or k==21:
            try:
                winners.append(idk[k].select('div')[i].select('div[class="winner"]')[0].select('span')[0].string)
                i+=3
            except:
                i=0
                k+=1
                continue
        else:
            i=0
            k+=1
            continue
    winners_int=[]
    for thing in winners:
        winners_int.append(int(thing))
    return winners_int

# %%
winners=get_winners ('https://www.sports-reference.com/cbb/postseason/2002-ncaa.html')

# %%
len(winners)
# Out:
# 63

# %%
import pandas as pd

# %%
df8 = pd.read_csv('newdf.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-dd702b45ca54> in <module>
# ----> 1 df8 = pd.read_csv('newdf.csv')
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'newdf.csv' does not exist

# %%
df8['team_name'] = team_names

# %%
df8['team_rank'] = rankings

# %%
df8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2df5975f13fb> in <module>
# ----> 1 df8
#
# NameError: name 'df8' is not defined

# %%
win = []
i = 0
for thing in list(df8['team_rank']):
    if list(df8['first_team'])[i] == list(df8['second_team'])[i]:
        win.append(9999)
    elif list(df8['team_rank'])[i] == list(df8['winner'])[i]:
        win.append(1)
    elif list(df8['team_rank'])[i] != list(df8['winner'])[i]:
        win.append(0)
    i+=1
df8['win']=win

# %%
list(df8['team_rank'])
# Out:
# [1,
#  16,
#  8,
#  9,
#  5,
#  12,
#  4,
#  13,
#  6,
#  11,
#  3,
#  14,
#  7,
#  10,
#  2,
#  15,
#  1,
#  8,
#  12,
#  4,
#  11,
#  3,
#  7,
#  2,
#  1,
#  4,
#  11,
#  2,
#  1,
#  2,
#  1,
#  16,
#  8,
#  9,
#  5,
#  12,
#  4,
#  13,
#  6,
#  11,
#  3,
#  14,
#  7,
#  10,
#  2,
#  15,
#  1,
#  8,
#  12,
#  4,
#  6,
#  3,
#  7,
#  2,
#  1,
#  4,
#  6,
#  2,
#  1,
#  2,
#  1,
#  16,
#  8,
#  9,
#  5,
#  12,
#  4,
#  13,
#  6,
#  11,
#  3,
#  14,
#  7,
#  10,
#  2,
#  15,
#  1,
#  8,
#  5,
#  13,
#  6,
#  3,
#  10,
#  2,
#  1,
#  5,
#  3,
#  10,
#  5,
#  10,
#  1,
#  16,
#  8,
#  9,
#  5,
#  12,
#  4,
#  13,
#  6,
#  11,
#  3,
#  14,
#  7,
#  10,
#  2,
#  15,
#  1,
#  8,
#  12,
#  4,
#  11,
#  3,
#  7,
#  2,
#  8,
#  12,
#  3,
#  2,
#  12,
#  2,
#  1,
#  1,
#  2,
#  5,
#  1,
#  5]

# %%
df8.to_csv('df8.csv')

# %%
df8
# Out:
#      Unnamed: 0  first_team  second_team  winner  point_difference  result  \
# 0             0           1           16       1                15       1
# 1             1           1           16       1                15       1
# 2             2           8            9       8                 1       1
# 3             3           8            9       8                 1       1
# 4             4           5           12      12                 7       2
# 5             5           5           12      12                 7       2
# 6             6           4           13       4                 9       1
# 7             7           4           13       4                 9       1
# 8             8           6           11      11                 5       2
# 9             9           6           11      11                 5       2
# 10           10           3           14       3                11       1
# 11           11           3           14       3                11       1
# 12           12           7           10       7                 3       1
# 13           13           7           10       7                 3       1
# 14           14           2           15       2                13       1
# 15           15           2           15       2                13       1
# 16           16           1            8       1                 7       1
# 17           17           1            8       1                 7       1
# 18           18          12            4       4                 8       1
# 19           19          12            4       4                 8       1
# 20           20          11            3      11                 8       2
# 21           21          11            3      11                 8       2
# 22           22           7            2       2                 5       1
# 23           23           7            2       2                 5       1
# 24           24           1            4       1                 3       1
# 25           25           1            4       1                 3       1
# 26           26          11            2       2                 9       1
# 27           27          11            2       2                 9       1
# 28           28           1            2       1                 1       1
# 29           29           1            2       1                 1       1
# ..          ...         ...          ...     ...               ...     ...
# 96           96           4           13       4                 9       1
# 97           97           4           13       4                 9       1
# 98           98           6           11      11                 5       2
# 99           99           6           11      11                 5       2
# 100         100           3           14       3                11       1
# 101         101           3           14       3                11       1
# 102         102           7           10       7                 3       1
# 103         103           7           10       7                 3       1
# 104         104           2           15       2                13       1
# 105         105           2           15       2                13       1
# 106         106           1            8       8                 7       2
# 107         107           1            8       8                 7       2
# 108         108          12            4      12                 8       2
# 109         109          12            4      12                 8       2
# 110         110          11            3       3                 8       1
# 111         111          11            3       3                 8       1
# 112         112           7            2       2                 5       1
# 113         113           7            2       2                 5       1
# 114         114           8           12      12                 4       2
# 115         115           8           12      12                 4       2
# 116         116           3            2       2                 1       1
# 117         117           3            2       2                 1       1
# 118         118          12            2       2                10       1
# 119         119          12            2       2                10       1
# 120         120           1            1       1                 0       0
# 121         121           1            1       1                 0       0
# 122         122           2            5       5                 3       2
# 123         123           2            5       5                 3       2
# 124         124           1            5       1                 4       1
# 125         125           1            5       1                 4       1
#
#              team_name  team_rank   win
# 0             Maryland          1     1
# 1                Siena         16     0
# 2            Wisconsin          8     1
# 3      St. John's (NY)          9     0
# 4            Marquette          5     0
# 5                Tulsa         12     1
# 6             Kentucky          4     1
# 7           Valparaiso         13     0
# 8           Texas Tech          6     0
# 9    Southern Illinois         11     1
# 10             Georgia          3     1
# 11        Murray State         14     0
# 12            NC State          7     1
# 13      Michigan State         10     0
# 14               UConn          2     1
# 15             Hampton         15     0
# 16            Maryland          1     1
# 17           Wisconsin          8     0
# 18               Tulsa         12     0
# 19            Kentucky          4     1
# 20   Southern Illinois         11     1
# 21             Georgia          3     0
# 22            NC State          7     0
# 23               UConn          2     1
# 24            Maryland          1     1
# 25            Kentucky          4     0
# 26   Southern Illinois         11     0
# 27               UConn          2     1
# 28            Maryland          1     1
# 29               UConn          2     0
# ..                 ...        ...   ...
# 96          Ohio State          4     1
# 97            Davidson         13     0
# 98             Gonzaga          6     0
# 99             Wyoming         11     1
# 100            Arizona          3     1
# 101               UCSB         14     0
# 102             Xavier          7     1
# 103             Hawaii         10     0
# 104           Oklahoma          2     1
# 105                UIC         15     0
# 106         Cincinnati          1     0
# 107               UCLA          8     1
# 108           Missouri         12     1
# 109         Ohio State          4     0
# 110            Wyoming         11     0
# 111            Arizona          3     1
# 112             Xavier          7     0
# 113           Oklahoma          2     1
# 114               UCLA          8     0
# 115           Missouri         12     1
# 116            Arizona          3     0
# 117           Oklahoma          2     1
# 118           Missouri         12     0
# 119           Oklahoma          2     1
# 120           Maryland          1  9999
# 121             Kansas          1  9999
# 122           Oklahoma          2     0
# 123            Indiana          5     1
# 124           Maryland          1     1
# 125            Indiana          5     0
#
# [126 rows x 9 columns]
